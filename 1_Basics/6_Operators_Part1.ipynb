# %%
2 + 3.0
# Out:
# 5.0

# %%
"What's " + "Up" + "!"
# Out:
# "What's Up!"

# %%
"What's " + "Up" + "!" *10
# Out:
# "What's Up!!!!!!!!!!"

# %%
"What's up? " *10
# Out:
# "What's up? What's up? What's up? What's up? What's up? What's up? What's up? What's up? What's up? What's up? "

# %%
3.0 - 2
# Out:
# 1.0

# %%
min_salary = 20_000
max_salary = 80_000

avg_salary = (min_salary + max_salary) / 2

avg_salary
# Out:
# 50000.0

# %%
applicant_1 = "Marin"
applicant_2 = "Adam"

# %%
temp_var = applicant_1

# %%
applicant_1 = applicant_2
applicant_2 = temp_var

# %%
applicant_1, applicant_2
# Out:
# ('Adam', 'Marin')

# %%
x = 1
x = x + 1
x
# Out:
# 2

# %%
x = 1
x+= 1 # x = x + 1
x
# Out:
# 2

# %%
x = 1
x *= 3
x
# Out:
# 3

# %%
salary_marin = 60_000
salary_adam = 40_000

# %%
salary_marin == salary_adam
# Out:
# False

# %%
if (salary_marin > salary_adam):
    print("Marin is paid more than Adam")
# Out:
# Marin is paid more than Adam
