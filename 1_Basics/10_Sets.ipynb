# %%
job_skills = {'tableau', 'sql', 'python', 'statistics'}

# %%
job_skills[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_13510/1926741740.py in <cell line: 0>()
# ----> 1 job_skills[1]
#
# TypeError: 'set' object is not subscriptable

# %%
job_skills.add('looker')

# %%
job_skills
# Out:
# {'looker', 'python', 'sql', 'statistics', 'tableau'}

# %%
job_skills.add('sql')

# %%
job_skills
# Out:
# {'looker', 'python', 'sql', 'statistics', 'tableau'}

# %%
job_skills.pop()
# Out:
# 'tableau'

# %%
job_skills.remove('statistics')

# %%
job_skills
# Out:
# {'looker', 'python', 'sql'}

# %%
skill_list = ['python', 'sql', 'statistics', 'tableau', 'python', 'sql', 'statistics', 'tableau']

# %%
set(skill_list)
# Out:
# {'python', 'sql', 'statistics', 'tableau'}

# %%
list(set(skill_list))
# Out:
# ['statistics', 'tableau', 'python', 'sql']
