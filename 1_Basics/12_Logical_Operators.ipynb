# %%
# Logical Operators

job_work_from_home = True
job_health_insurance = False
# job_no_degree_mention = True

job_work_from_home and job_health_insurance
# Out:
# False

# %%
job_work_from_home = False
job_health_insurance = False
job_no_degree_mention = True

job_work_from_home or job_health_insurance
# Out:
# False

# %%
if job_work_from_home or job_health_insurance or not job_no_degree_mention:
  print("meet conditions")

# %%
# Membership Operators

"Data" in "Data Nerd"
# Out:
# True

# %%
"data" in "Data Nerd"
# Out:
# False

# %%
job_skills = ['python', 'r', 'sql']

# %%
'python' in job_skills
# Out:
# True

# %%
# Identity Operators

salary_marin = 100_000
salary_adam = 100_000

salary_marin is salary_adam
# Out:
# False

# %%
core_skills = ['pyton', 'r', 'sql']
adam_skills = core_skills

adam_skills is core_skills
# Out:
# True

# %%
# Bitwise Op

bin(42)
# Out:
# '0b101010'
