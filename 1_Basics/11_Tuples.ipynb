# %%
adams_skills = ('python', 'sql', 'statistics', 'tableau')

# %%
adams_skills
# Out:
# ('python', 'sql', 'statistics', 'tableau')

# %%
adams_skills[0:2]
# Out:
# ('python', 'sql')

# %%
new_skills = ('excel', 'power bi')

# %%
adams_skills += new_skills

# %%
adams_skills
# Out:
# ('python', 'sql', 'statistics', 'tableau', 'excel', 'power bi')
