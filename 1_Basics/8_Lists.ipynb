# %%
my_list = [1, 'python', [2, 'sql']]

# %%
my_list
# Out:
# [1, 'python', [2, 'sql']]

# %%
job_skills = ['sql', 'tableau','excel']

# %%
job_skills.append('python')

# %%
job_skills
# Out:
# ['sql', 'tableau', 'excel', 'python']

# %%
job_skills.remove('tableau')

# %%
job_skills
# Out:
# ['sql', 'excel', 'python']

# %%
job_skills[1]
# Out:
# 'excel'

# %%
job_skills.insert(2, 'tableau')

# %%
job_skills
# Out:
# ['sql', 'excel', 'tableau', 'python']

# %%
job_skills.pop(2)
# Out:
# 'tableau'

# %%
job_skills
# Out:
# ['sql', 'excel', 'python']

# %%
job_skills.pop()
# Out:
# 'python'

# %%
job_skills = ['sql', 'excel', 'phyton']

# %%
job_skills[0:3]
# Out:
# ['sql', 'excel', 'phyton']

# %%
job_skills[:]
# Out:
# ['sql', 'excel', 'phyton']

# %%
job_skills[:1]
# Out:
# ['sql']

# %%
job_skills[::1]
# Out:
# ['sql', 'excel', 'phyton']

# %%
marin_skills = ['python', 'bigquery', 'r']
adam_skills = ['python', 'sql', 'looker']

all_skills = marin_skills +  adam_skills

all_skills
# Out:
# ['python', 'bigquery', 'r', 'python', 'sql', 'looker']

# %%
all_skills[::2]
# Out:
# ['python', 'r', 'sql']

# %%
job_skills = ['sql', 'excel', 'phyton','looker']

# %%
skill1,skill2,skill3 = job_skills

# %%
print(skill1)
print(skill2)
print(skill3)
# Out:
# sql
# excel
# phyton

# %%
skill_concerned, *skill_dont_care = job_skills

# %%
print(skill_concerned)
print(skill_dont_care)
# Out:
# sql
# ['excel', 'phyton', 'looker']
